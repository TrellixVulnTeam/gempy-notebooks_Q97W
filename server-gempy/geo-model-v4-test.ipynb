# %%
# standart libs
import sys
import random
import copy
from operator import itemgetter
from PIL import Image


# 3rd party libs
import pandas as pd
import numpy as np
import gempy as gp
import matplotlib.pyplot as plt
import scipy.stats as ss
from mpl_toolkits.axes_grid1 import make_axes_locatable


# local
import functions.realization_setup as real_setup
import functions.realization_run as real_run
import functions.post_processing as post_pro
import functions.uq_runs as uq_runs

# executable
print(sys.executable)
# Out:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/gempy_api.py:98: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if np.ndim(indices_array) is 1:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/gempy_api.py:101: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert form.shape[0] is 1, 'The interface points must belong to the same surface'
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/gempy_api.py:109: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif np.ndim(indices_array) is 2:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/gempy_api.py:112: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert form.shape[0] is 1, 'The interface points must belong to the same surface'
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/data.py:43: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if project_name is 'default_project':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/data.py:1356: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if attribute is 'series':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/data.py:2218: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert value.shape[0] is 3
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/data.py:2585: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if len_series_i.shape[0] is 0:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/grid_modules/grid_types.py:241: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert type(custom_grid) is np.ndarray and custom_grid.shape[1] is 3, 'The shape of new grid must be (n,3)' \
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/utils/create_topography.py:227: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if i is not 0 or j is not 0:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/utils/create_topography.py:227: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if i is not 0 or j is not 0:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/utils/create_topography.py:234: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if i is 0:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/utils/create_topography.py:239: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j is 0:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/interpolator.py:494: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if tz is None or tz is 'auto':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/interpolator.py:524: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if V is None or V is 'auto':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/theano/gof/op.py:1543: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   define_macros.append("#define INPUT_%d %s" (i, inp))
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/theano/gof/op.py:1547: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   define_macros.append("#define OUTPUT_%d %s" (i, inp))
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/theano/gof/opt.py:1287: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if len(tracks) is 0:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/theano/compile/mode.py:264: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if optimizer is 'default':
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# /home/stefan/coding/notebooks/env/bin/python
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/theano/tensor/nnet/bn.py:645: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   return [theano.gradient.DisconnectedType()() if r is 0 else r
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/plot/visualization_3d.py:210: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if key is 'h' or key is 'p':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/plot/visualization_3d.py:210: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if key is 'h' or key is 'p':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/plot/visualization_3d.py:215: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if key is 'l':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/plot/visualization_3d.py:227: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if key is 't':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/plot/visualization_3d.py:237: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if key is 'q':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/plot/visualization_3d.py:267: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if key is 'r':
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/plot/visualization_3d.py:672: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if int(obj.GetRepresentation().GetValue()) is 0:
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/plot/visualization_3d.py:1396: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if surface[1].values[0] is 0:

# %% [markdown]
# # Init the geo_model

# %%
# instantiate the geo_model
geo_model = gp.create_model("GeoModel")

# defautl data
geo_model = gp.init_data(
    geo_model,
    extent=[0, 1, 0, 1, 0, 1],
    resolution=[1, 1, 1]
)

# compile theno function
gp.set_interpolation_data(
    geo_model,
    compile_theano=True,
    theano_optimizer='fast_run',
)
# Out:
# Active grids: ['regular']
# Setting kriging parameters to their default values.
# Compiling theano function...
# Level of Optimization:  fast_run
# Device:  cpu
# Precision:  float64
# Number of faults:  0
# Compilation Done!
# Kriging values:
#                      values
# range              1.73205
# $C_o$            0.0714286
# drift equations        [3]

# %% [markdown]
# # Model data

# %% [markdown]
# ### Model 1

# %%
# meta
geo_model_extent_1 = [0,1000,0,1000,0,1000]
section_1 = {
    'p1': [0, 500],
    'p2': [1000, 500],
    'resolution': [200, 200]
}

# sereis
series_df_1 = pd.DataFrame(columns=['name', 'isfault', 'order_series'])
series_df_1.loc[0] = { 'order_series': 0, 'name': 'Basement_Series', 'isfault': False }
series_df_1.loc[1] = { 'order_series': 1, 'name': 'Strat_Series', 'isfault': False }

# surfaces
surfaces_df_1 = pd.DataFrame(columns=['name', 'serie', 'order_surface'])
surfaces_df_1.loc[0] = { 'name': 'basement', 'serie': 'Basement_Series', 'order_surface': 0 }
surfaces_df_1.loc[2] = { 'name': 'rock1', 'serie': 'Strat_Series', 'order_surface': 1 }
surfaces_df_1.loc[1] = { 'name': 'rock2', 'serie': 'Strat_Series', 'order_surface': 2 }

# geoData
surface_points_input_data_1 = pd.read_csv('./data/model2_surface_points.csv')
orientaions_input_data_1 = pd.read_csv('./data/model2_orientations.csv')

# Format geological_input_data
surface_points_original_df_1 = surface_points_input_data_1[['X', 'Y', 'Z', 'formation']]

# rename colums
surface_points_original_df_1.columns = ['X', 'Y', 'Z', 'surface']

# add distribution type and parameter
surface_points_original_df_1['param1'] = 10

# Orientaions
orientations_original_df_1 = orientaions_input_data_1[['X', 'Y', 'Z', 'dip', 'azimuth', 'polarity', 'formation']]

# %%
# %%timeit
# setup model 1
real_setup.setup_realization(
        geo_model=geo_model,
        geo_model_extent=geo_model_extent_1,
        section=section_1,
        series_df=series_df_1,
        surfaces_df=surfaces_df_1,
        surface_points_original_df=surface_points_original_df_1,
        orientations_original_df=orientations_original_df_1
)
# Out:
# Active grids: ['regular']
# Active grids: ['regular' 'sections']
# HOTFIX in update_series()
# HOTFIX in update_surfaces()

# %%
if real_run.check_setup_single_realization(geo_model):
    solution = gp.compute_model(model=geo_model, sort_surfaces=False)
# Out:
# Run realizations setup checks until stable workflow.
# HOTFIX in gempy/core/gempy_api.py 328
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/solution.py:196: FutureWarning: marching_cubes_lewiner is deprecated in favor of marching_cubes. marching_cubes_lewiner will be removed in version 0.19
#   vertices, simplices, normals, values = measure.marching_cubes_lewiner(

# %%
Bx = post_pro.compute_boolean_matrix_for_section_surface_top(geo_model)

# %%
# plot for sanity check
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.imshow(Bx['0-1'])
ax1.grid()
ax2.imshow(Bx['0-2'])
ax2.grid()
plt.show()

# %%
extent = { 'z_min': 0, 'z_max': 1000 }
section_coordinates = post_pro.compute_setction_grid_coordinates(geo_model, extent)

# %%
tops_dict = post_pro.get_tops_coordinates(Bx, section_coordinates)

# %%
plt.plot(tops_dict['0-1']['xvals'], tops_dict['0-1']['zvals'], '.')
plt.plot(
    geo_model.surface_points.df[geo_model.surface_points.df.surface == 'rock1']['X'],
    geo_model.surface_points.df[geo_model.surface_points.df.surface == 'rock1']['Z'],
    'o'
)

# %%
mapping_object = real_setup.creat_mapping_object(
    series_df=series_df_1,
    surfaces_df=surfaces_df_1
)

# %%
entropy_map = uq_runs.calulate_entropy_map(
    geo_model=geo_model,
    n_realization=10,
    surface_points_original_df=surface_points_original_df_1,
    orientations_original_df=orientations_original_df_1,
    section=section_1,
    mapping_object=mapping_object
)

plt.imshow(entropy_map.T, cmap='viridis')
plt.colorbar()
plt.show()
# Out:
# Realization: 0
# /home/stefan/coding/notebooks/env/lib/python3.8/site-packages/gempy/core/solution.py:196: FutureWarning: marching_cubes_lewiner is deprecated in favor of marching_cubes. marching_cubes_lewiner will be removed in version 0.19
#   vertices, simplices, normals, values = measure.marching_cubes_lewiner(
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 1
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 2
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 3
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 4
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 5
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 6
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 7
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 8
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 9
# HOTFIX in gempy/core/gempy_api.py 328

# %%
surface_points_original_df_1['param1'] = 20

entropy_map_a = uq_runs.calulate_entropy_map(
    geo_model=geo_model,
    n_realization=100,
    surface_points_original_df=surface_points_original_df_1,
    orientations_original_df=orientations_original_df_1,
    section=section_1,
    mapping_object=mapping_object
)

entropy_map_b = uq_runs.calulate_entropy_map(
    geo_model=geo_model,
    n_realization=100,
    surface_points_original_df=surface_points_original_df_1,
    orientations_original_df=orientations_original_df_1,
    section=section_1,
    mapping_object=mapping_object
)

xa, ya = np.where(entropy_map_a)
sa = entropy_map_a[xa, ya]
xb, yb = np.where(entropy_map_b)
sb = entropy_map_a[xb, yb]
yb = yb + 40
A = np.zeros(entropy_map_a.shape)
A[xa, ya] = sa
A[xb, yb] = sb
plt.imshow(A.T[::-1,:], cmap='viridis')
# Out:
# Realization: 0
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 1
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 2
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 3
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 4
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 5
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 6
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 7
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 8
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 9
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 10
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 11
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 12
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 13
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 14
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 15
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 16
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 17
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 18
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 19
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 20
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 21
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 22
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 23
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 24
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 25
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 26
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 27
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 28
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 29
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 30
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 31
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 32
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 33
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 34
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 35
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 36
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 37
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 38
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 39
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 40
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 41
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 42
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 43
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 44
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 45
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 46
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 47
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 48
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 49
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 50
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 51
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 52
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 53
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 54
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 55
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 56
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 57
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 58
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 59
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 60
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 61
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 62
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 63
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 64
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 65
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 66
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 67
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 68
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 69
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 70
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 71
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 72
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 73
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 74
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 75
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 76
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 77
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 78
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 79
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 80
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 81
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 82
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 83
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 84
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 85
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 86
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 87
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 88
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 89
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 90
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 91
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 92
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 93
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 94
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 95
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 96
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 97
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 98
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 99
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 0
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 1
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 2
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 3
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 4
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 5
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 6
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 7
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 8
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 9
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 10
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 11
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 12
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 13
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 14
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 15
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 16
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 17
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 18
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 19
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 20
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 21
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 22
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 23
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 24
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 25
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 26
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 27
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 28
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 29
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 30
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 31
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 32
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 33
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 34
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 35
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 36
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 37
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 38
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 39
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 40
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 41
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 42
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 43
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 44
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 45
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 46
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 47
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 48
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 49
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 50
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 51
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 52
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 53
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 54
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 55
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 56
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 57
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 58
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 59
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 60
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 61
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 62
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 63
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 64
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 65
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 66
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 67
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 68
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 69
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 70
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 71
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 72
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 73
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 74
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 75
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 76
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 77
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 78
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 79
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 80
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 81
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 82
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 83
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 84
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 85
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 86
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 87
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 88
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 89
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 90
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 91
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 92
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 93
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 94
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 95
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 96
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 97
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 98
# HOTFIX in gempy/core/gempy_api.py 328
# Realization: 99
# HOTFIX in gempy/core/gempy_api.py 328

# %%
fig, (ax0) = plt.subplots(nrows=1, ncols=1, figsize=(20, 20))
pos = ax0.imshow(A.T[:,:], cmap='viridis', interpolation='none')
ax0.set_xlim([0,198])
ax0.set_ylim([0,198])
ax0.set_yticklabels([])
ax0.set_xticklabels([])
# ax0.set_title('Information entropy')

divider = make_axes_locatable(ax0)
cax = divider.append_axes("right", size="5%", pad=.05)
plt.colorbar(pos, cax=cax)

# fig.colorbar(pos, ax=ax0)
fig.savefig('./entropy.png')
plt.show()

# %% [markdown]
# ### Model 2

# %%
geo_model_extent_2 = [0,2000,0,2000,0,2000]
section_2 = {
    'p1': [0, 1000],
    'p2': [2000, 1000],
    'resolution': [200, 200]
}

series_df_2 = pd.read_csv('./data/simple_fault_model_series.csv')
series_df_2['order_surface'] = [0,1]
surfaces_df_2 = pd.read_csv('./data/simple_fault_model_surfaces.csv')
surfaces_df_2['order_surface'] = [0,1,2,3,4,5]

surface_points_input_data_2 = pd.read_csv('./data/simple_fault_model_points.csv')
orientaions_input_data_2 = pd.read_csv('./data/simple_fault_model_orientations.csv')

# Format geological_input_data
surface_points_original_df_2 = surface_points_input_data_2[['X', 'Y', 'Z', 'formation']]

# rename colums
surface_points_original_df_2.columns = ['X', 'Y', 'Z', 'surface']

# add distribution type and parameter
surface_points_original_df_2['param1'] = 10

# Orientaions
orientations_original_df_2 = orientaions_input_data_2[['X', 'Y', 'Z', 'dip', 'azimuth', 'polarity', 'formation']]

# %%
# %%timeit
real_setup.setup_realization(
        geo_model=geo_model,
        geo_model_extent=geo_model_extent_2,
        section=section_2,
        series_df=series_df_2,
        surfaces_df=surfaces_df_2,
        surface_points_original_df=surface_points_original_df_2,
        orientations_original_df=orientations_original_df_2
)
# Out:
# Active grids: ['regular' 'sections']
# Active grids: ['regular' 'sections']
# HOTFIX in update_series()
# Fault colors changed. If you do not like this behavior, set change_color to False.

# %%
solution = gp.compute_model(model=geo_model, sort_surfaces=False)
# Out:
# HOTFIX in gempy/core/gempy_api.py 328

# %%
if real_run.check_setup_single_realization(geo_model):
    solution = gp.compute_model(model=geo_model, sort_surfaces=False)
# Out:
# Run realizations setup checks until stable workflow.
# HOTFIX in gempy/core/gempy_api.py 328

# %%
Bx = post_pro.compute_boolean_matrix_for_section_surface_top(geo_model)

# %%
# plot for sanity check
fig, axs = plt.subplots(2, 3)
axs[0,0].imshow(Bx['1-1'])
axs[0,0].grid()
axs[0,1].imshow(Bx['1-2'])
axs[0,1].grid()
axs[0,2].imshow(Bx['1-3'])
axs[0,2].grid()
axs[1,0].imshow(Bx['1-4'])
axs[1,0].grid()
axs[1,1].imshow(Bx['1-0'])
axs[1,1].grid()
axs[1,2].imshow(Bx['0-1'])
axs[1,2].grid()
plt.show()

# %%
extent = { 'z_min': 0, 'z_max': 2000 }
section_coordinates = post_pro.compute_setction_grid_coordinates(geo_model, extent)

# %%
tops_dict = post_pro.get_tops_coordinates(Bx, section_coordinates)

# %%
post_pro.plot_tops(tops_dict, 'large_model_tops', 0, 2000, 0, 2000)

#img1 = Image.open('./snapshots/small_model_tops_prototype.png')
#img2 = Image.open('./snapshots/small_model_tops.png')
#diff = np.fabs(np.subtract(img2, img1))
#print(np.sum(diff) == 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-a27e16484990> in <module>
# ----> 1 post_pro.plot_tops(tops_dict, 'large_model_tops', 0, 2000, 0, 2000)
#       2
#       3 #img1 = Image.open('./snapshots/small_model_tops_prototype.png')
#       4 #img2 = Image.open('./snapshots/small_model_tops.png')
#       5 #diff = np.fabs(np.subtract(img2, img1))
#
# ~/coding/notebooks/server-gempy/functions/post_processing.py in plot_tops(tops_coordinates, name, xmin, xmax, ymin, ymax)
#     208     ax.set_ylim(ymin, ymax)
#     209     file_location = './snapshots/' + name + '.png'
# --> 210     fig.savefig(file_location)
#
# ~/coding/notebooks/env/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~/coding/notebooks/env/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# ~/coding/notebooks/env/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /usr/lib/python3.8/contextlib.py in __enter__(self)
#     111         del self.args, self.kwds, self.func
#     112         try:
# --> 113             return next(self.gen)
#     114         except StopIteration:
#     115             raise RuntimeError("generator didn't yield") from None
#
# ~/coding/notebooks/env/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# ~/coding/notebooks/env/lib/python3.8/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './snapshots/large_model_tops.png'

# %%
surfaces_df_2.sort_values(by=['order_surface'], inplace=True)

# %%
mapping_object = real_setup.creat_mapping_object(
    series_df=series_df_2,
    surfaces_df=surfaces_df_2
)

# %%
entropy_map = uq_runs.calulate_entropy_map(
    geo_model=geo_model,
    n_realization=10,
    surface_points_original_df=surface_points_original_df_2,
    orientations_original_df=orientations_original_df_2,
    section=section_2,
    mapping_object=mapping_object
)

plt.imshow(entropy_map[:,::-1].T, cmap='viridis')
plt.colorbar()
plt.show()
